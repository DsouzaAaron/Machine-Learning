# %% [markdown]
# # Analysis of  'Cancer' Dataset using SVM model to predict the class of Cancer

# %% [markdown]
# MetaData-<br>
# <ol>
#     <li>ID number</li>
#     <li>Diagnosis (M = malignant, B = benign)</li>
# <li>32)
# Ten real-valued features are computed for each cell nucleus:
#
# a) radius (mean of distances from center to points on the perimeter)<br>
# b) texture (standard deviation of gray-scale values)<br>
# c) perimeter<br>
# d) area<br>
# e) smoothness (local variation in radius lengths)<br>
# f) compactness (perimeter^2 / area - 1.0)<br>
# g) concavity (severity of concave portions of the contour)<br>
# h) concave points (number of concave portions of the contour)<br>
# i) symmetry<br>
# j) fractal dimension ("coastline approximation" - 1)<br>
#     </li>
# </ol>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
warnings.filterwarnings('ignore')
df = pd.read_csv("cancer.csv")
df
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0      842302         M        17.99         10.38          122.80     1001.0
# 1      842517         M        20.57         17.77          132.90     1326.0
# 2    84300903         M        19.69         21.25          130.00     1203.0
# 3    84348301         M        11.42         20.38           77.58      386.1
# 4    84358402         M        20.29         14.34          135.10     1297.0
# ..        ...       ...          ...           ...             ...        ...
# 564    926424         M        21.56         22.39          142.00     1479.0
# 565    926682         M        20.13         28.25          131.20     1261.0
# 566    926954         M        16.60         28.08          108.30      858.1
# 567    927241         M        20.60         29.33          140.10     1265.0
# 568     92751         B         7.76         24.54           47.92      181.0
#
# ...

# %% [markdown]
# <h3> Preprocessing

# %%
df.shape
# Out:
# (569, 33)

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
df=df.iloc[:,:-1]
df.iloc[:,2:].describe()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# <h3> Vizualizating Distribution of numeric attributes

# %%
column = list(df.iloc[:,2:].columns)
for i in range(len(column)):
    plt.figure(figsize=(7,5))
    sns.histplot(data=df,x=column[i])
    plt.title(column[i])
    plt.show()

# %% [markdown]
# Encoding the diagnosis attribute; 0 - Bengin, 1 - Malignant

# %%
# Encodiing using LabelEncoder
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

df["diagnosis"] = le.fit_transform(df["diagnosis"])

# %%
# Setting the independent and target attribute
x = df.iloc[:,2:]
y = df["diagnosis"]

# %% [markdown]
# <h3> Splitting the Dataset into Train and Test

# %%
# Splitting the dataset
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# <h3> Tuning the Hyperparameters of SVM model using GridSearchCV

# %%
# Finding the best SVM model
from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler

x_train = RobustScaler().fit_transform(x_train)
params = {
    "C": np.arange(0,10),
    "kernel":['linear', 'poly', 'rbf'],
    #"degree":[2,3,4,5],
    "gamma":['auto','scale']
}

svc = SVC()
svc.fit(x_train,y_train)
gs = GridSearchCV(svc,param_grid=params,n_jobs=-1,cv=5,refit=True, verbose = 3)
gs.fit(x_train,y_train)
gs.best_params_
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# {'C': 8, 'gamma': 'scale', 'kernel': 'rbf'}

# %% [markdown]
# The best SVM model has values C = 8,  gama = 'scale',  kernel = 'rbf'

# %% [markdown]
# <h3>Model Evaluation

# %%
gs.best_score_
# Out:
# 0.9824683544303797

# %%
from sklearn.metrics import classification_report
# train the best model on train set using the hyperparameter values
best_clf = SVC(C=8,gamma='scale',kernel='rbf')
best_clf.fit(x_train, y_train)
 
# print prediction results
x_test = RobustScaler().fit_transform(x_test)
y_pred = best_clf.predict(x_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.97       103
#            1       0.97      0.93      0.95        68
#
#     accuracy                           0.96       171
#    macro avg       0.96      0.95      0.96       171
# weighted avg       0.96      0.96      0.96       171

# %%
from sklearn.metrics import accuracy_score
print("Accuracy: ",accuracy_score(y_test,y_pred))
# Out:
# Accuracy:  0.9590643274853801

# %% [markdown]
# The Accuracy of the model found by tuning hyperparameters is 0.96 which is a good performance
